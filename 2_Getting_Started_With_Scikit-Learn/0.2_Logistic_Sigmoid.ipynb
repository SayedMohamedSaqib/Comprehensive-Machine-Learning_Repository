# %% [markdown]
# ### It is inverse of logit function as it projects real number values in range 0 to 1 with 0.5 as intercept, commonly used as activation function for logistic regression

# %%
import matplotlib.pyplot as plt 
import numpy as np 

def sigmoid(z) :
    return 1.0 / (1.0 + np.exp(-z))

z = np.arange(-7, 7, 0.1)


phi_z = sigmoid(z)
plt.plot(z, phi_z)

# Draws a vertical line at x = 0, k = black color
plt.axvline(0.0, color='k')

plt.ylim(-0.1, 1.1)
plt.xlabel('z')
plt.ylabel('$\phi (z)$')

# y axis ticks and gridline
plt.yticks([0.0, 0.5, 1.0])

# Returns the graph object so we can customize it
ax = plt.gca() # get current axis

# Add horizontal lines
ax.yaxis.grid(True)

plt.tight_layout()
plt.show()
